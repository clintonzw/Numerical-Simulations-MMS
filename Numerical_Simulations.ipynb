# %% [markdown]
# # Numerical Simulations
#
# We have 13 variables. We will be investigating the behaviour of tick-born diseases under different parameter values.

# %% [markdown]
# ## Host Vertebrate

# %%
# @title $S_{H}$ - Host vertebrate susceptible population dynamics:
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.05
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/(P0S + PS * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt,
            dITdt, dPPdt, dPgdt, dPzdt, dPkdt, dPsdt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,0],'g-', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$S_{H}[t]$")
plt.legend(["$S_{H}$"])
plt.show()

# %%
# @title $I_{H}$ - Host vertebrate infectious population dynamics:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.05
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/(P0S + PS * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * Pp * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt,
            dITdt, dPPdt, dPgdt, dPzdt, dPkdt, dPsdt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

#plt.plot(t,n[:,0],'g-', linewidth=2.0)
plt.plot(t,n[:,1],'r-', linewidth=2.0)
# plt.plot(t,n[:,23],'b--', linewidth=2.0)
# plt.plot(t,n[:,34],'r--', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$I_{H}[t]$")
plt.legend(["$I_{H}$"])
plt.show()

# %%
# @title Host vertebrate susceptible population dynamics under  different $\beta_{T}$ values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.03
    betaT1 = 0.05
    betaT2 = 0.07
    betaT3 = 0.1
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/(P0S + PS * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT1 * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT1 * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT + 1) - alphaS * PS1
    dPh1dt = (betaT1 * PS1 * (SH1 - 1))/(P0S + PS1 * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH * PP1 * (ST - 1))/((P0P + PP1) * phiT * (IT + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT2 * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT2 * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT2 * PS2 * (SH2 - 1))/(P0S + PS2 * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH + 1) - alphaP * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT3 * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT3 * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT3 * PS3 * (SH3 - 1))/(P0S + PS3 * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,0],'g-', linewidth=2.0)
plt.plot(t,n[:,13],'y-', linewidth=2.0)
plt.plot(t,n[:,26],'b-', linewidth=2.0)
plt.plot(t,n[:,39],'r-', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$S_{H} [t]$")
plt.legend(["$\u03B2_T = 0.03$","$\u03B2_T = 0.05$", "$\u03B2_T = 0.07$","$\u03B2_T = 0.1$"])
plt.show()

# %%
# @title Host vertebrate infectious population dynamics under different $\beta_{T}$ values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.03
    betaT1 = 0.05
    betaT2 = 0.07
    betaT3 = 0.1
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/(P0S + PS * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT1 * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT1 * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT + 1) - alphaS * PS1
    dPh1dt = (betaT1 * PS1 * (SH1 - 1))/(P0S + PS1 * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH * PP1 * (ST - 1))/((P0P + PP1) * phiT * (IT + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT2 * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT2 * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT2 * PS2 * (SH2 - 1))/(P0S + PS2 * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH + 1) - alphaP * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT3 * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT3 * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT3 * PS3 * (SH3 - 1))/(P0S + PS3 * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,1],'g-', linewidth=2.0)
plt.plot(t,n[:,14],'y-', linewidth=2.0)
plt.plot(t,n[:,27],'b-', linewidth=2.0)
plt.plot(t,n[:,40],'r-', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$I_{H} [t]$")
plt.legend(["$\u03B2_T = 0.03$","$\u03B2_T = 0.05$", "$\u03B2_T = 0.07$","$\u03B2_T = 0.1$"])
plt.show()

# %%
# @title Host vertebrate susceptible population dynamics under different $\alpha_{k}$ values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.05
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 0.00002
    alphak1 = 0.00004
    alphak2 = 0.00009
    alphak3 = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/((P0S + PS) * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT + 1) - alphaS * PS1
    dPh1dt = (betaT * PS1 * (SH1 - 1))/((P0S + PS1) * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH * PP1 * (ST - 1))/((P0P + PP1) * phiT * (IT + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak1 + muk) * Pk1
    dPs1dt = alphak1 * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT * PS2 * (SH2 - 1))/((P0S + PS2) * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH + 1) - alphaP * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak2 + muk) * Pk2
    dPs2dt = alphak2 * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT * PS3 * (SH3 - 1))/((P0S + PS3) * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak3 + muk) * Pk3
    dPs3dt = alphak3 * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,0],'g--', linewidth=2.0)
plt.plot(t,n[:,13],'y--', linewidth=2.0)
plt.plot(t,n[:,26],'b--', linewidth=2.0)
plt.plot(t,n[:,39],'r--', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$S_{H} [t]$")
plt.legend(["$\u03B1_k = 0.00002$","$\u03B1_k = 0.00004$", "$\u03B1_k = 0.00009$","$\u03B1_k = 30$"])
plt.show()

# %%
# @title Host vertebrate infectious population dynamics under different $\alpha_{k}$ values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.05
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 0.00002
    alphak1 = 0.00004
    alphak2 = 0.00009
    alphak3 = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/((P0S + PS) * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT + 1) - alphaS * PS1
    dPh1dt = (betaT * PS1 * (SH1 - 1))/((P0S + PS1) * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH * PP1 * (ST - 1))/((P0P + PP1) * phiT * (IT + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak1 + muk) * Pk1
    dPs1dt = alphak1 * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT * PS2 * (SH2 - 1))/((P0S + PS2) * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH + 1) - alphaP * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak2 + muk) * Pk2
    dPs2dt = alphak2 * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT * PS3 * (SH3 - 1))/((P0S + PS3) * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak3 + muk) * Pk3
    dPs3dt = alphak3 * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,1],'g--', linewidth=2.0)
plt.plot(t,n[:,14],'y--', linewidth=2.0)
plt.plot(t,n[:,27],'b--', linewidth=2.0)
plt.plot(t,n[:,40],'r--', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$I_{H} [t]$")
plt.legend(["$\u03B1_k = 0.00002$","$\u03B1_k = 0.00004$", "$\u03B1_k = 0.00009$","$\u03B1_k = 30$"])
plt.show()

# %%
# @title $P_{h}$ dynamics under different $\beta_{T}$ values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.000085
    betaT1 = 0.0002
    betaT2 = 0.0003
    betaT3 = 0.0005
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/((P0S + PS) * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT1 * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT1 * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT1 + 1) - alphaS * PS1
    dPh1dt = (betaT1 * PS1 * (SH1 - 1))/((P0S + PS1) * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH * PP1 * (ST1 - 1))/((P0P + PP1) * phiT * (IT1 + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT2 * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT2 * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT2 * PS2 * (SH2 - 1))/((P0S + PS2) * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH2 + 1) - alphaP * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT3 * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT3 * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT3 * PS3 * (SH3 - 1))/((P0S + PS3) * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,3],'g--', linewidth=2.0)
plt.plot(t,n[:,16],'y--', linewidth=2.0)
plt.plot(t,n[:,29],'b--', linewidth=2.0)
plt.plot(t,n[:,42],'r--', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$P_{h} [t]$")
plt.legend(["$\u03B2_T = 0.000085$","$\u03B2_T = 0.0002$", "$\u03B2_T = 0.0003$","$\u03B2_T = 0.0005$"])
plt.show()

# %%
# @title $P_{p}$ dynamics under different $\beta_{T}$ values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.01
    betaT1 = 0.03
    betaT2 = 0.09
    betaT3 = 0.36
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/((P0S + PS) * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT1 * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT1 * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT1 + 1) - alphaS * PS1
    dPh1dt = (betaT1 * PS1 * (SH1 - 1))/((P0S + PS1) * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH * PP1 * (ST1 - 1))/((P0P + PP1) * phiT * (IT1 + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT2 * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT2 * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT2 * PS2 * (SH2 - 1))/((P0S + PS2) * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH2 + 1) - alphaP * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT3 * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT3 * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT3 * PS3 * (SH3 - 1))/((P0S + PS3) * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,5],'g--', linewidth=2.0)
plt.plot(t,n[:,18],'y--', linewidth=2.0)
plt.plot(t,n[:,31],'b--', linewidth=2.0)
plt.plot(t,n[:,44],'r--', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$P_{p} [t]$")
plt.legend(["$\u03B2_T = 0.01$","$\u03B2_T = 0.03$", "$\u03B2_T = 0.09$","$\u03B2_T = 0.36$"])
plt.show()

# %%
# @title $P_{m}$ dynamics under different $\beta_{T}$ values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.000085
    betaT1 = 0.0002
    betaT2 = 0.0003
    betaT3 = 0.0005
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/((P0S + PS) * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT1 * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT1 * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT1 + 1) - alphaS * PS1
    dPh1dt = (betaT1 * PS1 * (SH1 - 1))/((P0S + PS1) * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH * PP1 * (ST1 - 1))/((P0P + PP1) * phiT * (IT1 + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT2 * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT2 * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT2 * PS2 * (SH2 - 1))/((P0S + PS2) * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH2 + 1) - alphaP * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT3 * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT3 * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT3 * PS3 * (SH3 - 1))/((P0S + PS3) * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,4],'g--', linewidth=2.0)
plt.plot(t,n[:,17],'y--', linewidth=2.0)
plt.plot(t,n[:,30],'b--', linewidth=2.0)
plt.plot(t,n[:,43],'r--', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$P_{m} [t]$")
plt.legend(["$\u03B2_T = 0.000085$","$\u03B2_T = 0.0002$", "$\u03B2_T = 0.0003$","$\u03B2_T = 0.0005$"])
plt.show()

# %%
# @title Pathogen (Host Vertebrate) dynamics under different $\delta_{H}$ values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.05
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.01
    deltaH1 = 0.03
    deltaH2 = 0.06
    deltaH3 = 0.1
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/((P0S + PS) * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT * PS1 * SH1)/(P0S + PS1) - (deltaH1 + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT + 1) - alphaS * PS1
    dPh1dt = (betaT * PS1 * (SH1 - 1))/((P0S + PS1) * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH * PP1 * (ST - 1))/((P0P + PP1) * phiT * (IT + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT * PS2 * SH2)/(P0S + PS2) - (deltaH2 + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT * PS2 * (SH2 - 1))/((P0S + PS2) * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH2 + 1) - alphaP * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT * PS3 * SH3)/(P0S + PS3) - (deltaH3 + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT * PS3 * (SH3 - 1))/((P0S + PS3) * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,8],'g-.', linewidth=2.0)
plt.plot(t,n[:,21],'y-.', linewidth=2.0)
plt.plot(t,n[:,34],'b-.', linewidth=2.0)
plt.plot(t,n[:,47],'r-.', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$P_{P} [t]$")
plt.legend(["$\u03B4_H = 0.01$","$\u03B4_H = 0.03$", "$\u03B4_H = 0.06$","$\u03B4_H = 0.1$"])
plt.show()

# %% [markdown]
# ## Tick

# %%
# @title $S_T$ - Tick susceptible population dynamics:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.05
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/((P0S + PS) * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt,
            dITdt, dPPdt, dPgdt, dPzdt, dPkdt, dPsdt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,6],'g-', linewidth=2.0)
#plt.plot(t,n[:,7],'r-', linewidth=2.0)
# plt.plot(t,n[:,23],'b--', linewidth=2.0)
# plt.plot(t,n[:,34],'r--', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$S_{T}[t]$")
plt.legend(["$S_{T}$"])
plt.show()

# %%
# @title $I_T$ - Tick infectious population dynamics:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.05
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/(P0S + PS * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * Pp * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt,
            dITdt, dPPdt, dPgdt, dPzdt, dPkdt, dPsdt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

#plt.plot(t,n[:,6],'g-', linewidth=2.0)
plt.plot(t,n[:,7],'r-', linewidth=2.0)
# plt.plot(t,n[:,23],'b--', linewidth=2.0)
# plt.plot(t,n[:,34],'r--', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$I_{T}[t]$")
plt.legend(["$I_{T}$"])
plt.show()

# %%
# @title Tick susceptible population dynamics under different $\beta_{H}$ values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.002
    betaH = 0.02
    betaH1 = 0.07
    betaH2 = 0.12
    betaH3 = 0.2
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/(P0S + PS * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT + 1) - alphaS * PS1
    dPh1dt = (betaT * PS1 * (SH1 - 1))/(P0S + PS1 * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH1 * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH1 * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH1 * PP1 * (ST - 1))/((P0P + PP1) * phiT * (IT + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT * PS2 * (SH2 - 1))/(P0S + PS2 * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH2 * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH2 * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH + 1) - alphaP * PP2
    dPg2dt = (betaH2 * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT * PS3 * (SH3 - 1))/(P0S + PS3 * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH3 * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH3 * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH3 * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,6],'g-', linewidth=2.0)
plt.plot(t,n[:,19],'y-', linewidth=2.0)
plt.plot(t,n[:,32],'b-', linewidth=2.0)
plt.plot(t,n[:,45],'r-', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$S_{T} [t]$")
plt.legend(["$\u03B2_H = 0.02$","$\u03B2_H = 0.07$", "$\u03B2_H = 0.12$","$\u03B2_H = 0.2$"])
plt.show()

# %%
# @title Tick infectious population dynamics under different βH values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.002
    betaH = 0.02
    betaH1 = 0.07
    betaH2 = 0.12
    betaH3 = 0.2
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/(P0S + PS * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT + 1) - alphaS * PS1
    dPh1dt = (betaT * PS1 * (SH1 - 1))/(P0S + PS1 * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH1 * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH1 * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH1 * PP1 * (ST - 1))/((P0P + PP1) * phiT * (IT + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT * PS2 * (SH2 - 1))/(P0S + PS2 * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH2 * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH2 * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH + 1) - alphaP * PP2
    dPg2dt = (betaH2 * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT * PS3 * (SH3 - 1))/(P0S + PS3 * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH3 * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH3 * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH3 * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,7],'g-', linewidth=2.0)
plt.plot(t,n[:,20],'y-', linewidth=2.0)
plt.plot(t,n[:,33],'b-', linewidth=2.0)
plt.plot(t,n[:,46],'r-', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$I_{T} [t]$")
plt.legend(["$\u03B2_H = 0.02$","$\u03B2_H = 0.07$", "$\u03B2_H = 0.12$","$\u03B2_H = 0.2$"])
plt.show()

# %%
# @title Tick infectious population dynamics under different $\alpha_{p}$ values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.002
    betaH = 0.12
    alphah = 0.0000001
    alphah1 = 0.0000005
    alphah2 = 0.00001
    alphah3 = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/((P0S + PS) * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT + 1) - alphaS * PS1
    dPh1dt = (betaT * PS1 * (SH1 - 1))/((P0S + PS1) * phiH * (IH1 + 1)) - (alphah1 + muh) * Ph1
    dPm1dt = alphah1 * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH * PP1 * (ST - 1))/((P0P + PP1) * phiT * (IT + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT * PS2 * (SH2 - 1))/((P0S + PS2) * phiH * (IH2 + 1)) - (alphah2 + muh) * Ph2
    dPm2dt = alphah2 * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH2 + 1) - alphaP * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT * PS3 * (SH3 - 1))/(P0S + PS3 * phiH * (IH3 + 1)) - (alphah3 + muh) * Ph3
    dPm3dt = alphah3 * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,7],'g--', linewidth=2.0)
plt.plot(t,n[:,20],'y--', linewidth=2.0)
plt.plot(t,n[:,33],'b--', linewidth=2.0)
plt.plot(t,n[:,46],'r--', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$I_{T} [t]$")
plt.legend(["$\u03B1_h = 0.0000001$","$\u03B1_h = 0.0000005$", "$\u03B1_h = 0.00001$","$\u03B1_h= 90$"])
plt.show()

# %%
# @title Tick susceptible population dynamics under different $\alpha_{m}$ values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.002
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 0.0000001
    alpham1 = 0.0000007
    alpham2 = 0.000009
    alpham3 = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/((P0S + PS) * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT + 1) - alphaS * PS1
    dPh1dt = (betaT * PS1 * (SH1 - 1))/((P0S + PS1) * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham1 + mum) * Pm1
    dPp1dt = alpham1 * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH * PP1 * (ST - 1))/((P0P + PP1) * phiT * (IT + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT * PS2 * (SH2 - 1))/((P0S + PS2) * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham2 + mum) * Pm2
    dPp2dt = alpham2 * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH + 1) - alphaP * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT * PS3 * (SH3 - 1))/((P0S + PS3) * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham3 + mum) * Pm3
    dPp3dt = alpham3 * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,6],'g--', linewidth=2.0)
plt.plot(t,n[:,19],'y--', linewidth=2.0)
plt.plot(t,n[:,32],'b--', linewidth=2.0)
plt.plot(t,n[:,45],'r--', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$S_{T} [t]$")
plt.legend(["$\u03B1_m = 0.0000001$","$\u03B1_m = 0.0000007$", "$\u03B1_m = 0.000009$","$\u03B1_m= 80$"])
plt.show()

# %%
# @title Tick infectious population dynamics under different αm values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.002
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 0.0000001
    alpham1 = 0.0000007
    alpham2 = 0.000009
    alpham3 = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/((P0S + PS) * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT + 1) - alphaS * PS1
    dPh1dt = (betaT * PS1 * (SH1 - 1))/((P0S + PS1) * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham1 + mum) * Pm1
    dPp1dt = alpham1 * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH * PP1 * (ST - 1))/((P0P + PP1) * phiT * (IT + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT * PS2 * (SH2 - 1))/((P0S + PS2) * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham2 + mum) * Pm2
    dPp2dt = alpham2 * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH + 1) - alphaP * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT * PS3 * (SH3 - 1))/((P0S + PS3) * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham3 + mum) * Pm3
    dPp3dt = alpham3 * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,7],'g--', linewidth=2.0)
plt.plot(t,n[:,20],'y--', linewidth=2.0)
plt.plot(t,n[:,33],'b--', linewidth=2.0)
plt.plot(t,n[:,46],'r--', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$I_{T} [t]$")
plt.legend(["$\u03B1_m = 0.0000001$","$\u03B1_m = 0.0000007$", "$\u03B1_m = 0.000009$","$\u03B1_m= 80$"])
plt.show()

# %%
# @title Tick infectious population dynamics under different $\alpha_{p}$ values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.002
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.0000001
    alphap1 = 0.0000004
    alphap2 = 0.000004
    alphap3 = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/((P0S + PS) * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT + 1) - alphaS * PS1
    dPh1dt = (betaT * PS1 * (SH1 - 1))/((P0S + PS1) * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap1 + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap1 * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH * PP1 * (ST - 1))/((P0P + PP1) * phiT * (IT + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT * PS2 * (SH2 - 1))/((P0S + PS2) * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap2 + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap2 * Pp2 * (IH2 + 1) - alphaP * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT * PS3 * (SH3 - 1))/((P0S + PS3) * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap3 + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap3 * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,7],'g--', linewidth=2.0)
plt.plot(t,n[:,20],'y--', linewidth=2.0)
plt.plot(t,n[:,33],'b--', linewidth=2.0)
plt.plot(t,n[:,46],'r--', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$I_{T} [t]$")
plt.legend(["$\u03B1_p = 0.0000001$","$\u03B1_p = 0.0000004$", "$\u03B1_p = 0.000004$","$\u03B1_p= 0.04$"])
plt.show()

# %%
# @title Tick susceptible population dynamics under different $\alpha_{h}$ values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.002
    betaH = 0.12
    alphah = 0.0000001
    alphah1 = 0.0000005
    alphah2 = 0.00001
    alphah3 = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/((P0S + PS) * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT + 1) - alphaS * PS1
    dPh1dt = (betaT * PS1 * (SH1 - 1))/((P0S + PS1) * phiH * (IH1 + 1)) - (alphah1 + muh) * Ph1
    dPm1dt = alphah1 * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH * PP1 * (ST - 1))/((P0P + PP1) * phiT * (IT + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT * PS2 * (SH2 - 1))/((P0S + PS2) * phiH * (IH2 + 1)) - (alphah2 + muh) * Ph2
    dPm2dt = alphah2 * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH2 + 1) - alphaP * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT * PS3 * (SH3 - 1))/((P0S + PS3) * phiH * (IH3 + 1)) - (alphah3 + muh) * Ph3
    dPm3dt = alphah3 * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,6],'g--', linewidth=2.0)
plt.plot(t,n[:,19],'y--', linewidth=2.0)
plt.plot(t,n[:,32],'b--', linewidth=2.0)
plt.plot(t,n[:,45],'r--', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$S_{T} [t]$")
plt.legend(["$\u03B1_h = 0.0000001$","$\u03B1_h = 0.0000005$", "$\u03B1_h = 0.00001$","$\u03B1_h= 90$"])
plt.show()

# %%
# @title Tick susceptible population dynamics under different $\alpha_{p}$ values:

import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.002
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.0000001
    alphap1 = 0.0000004
    alphap2 = 0.000004
    alphap3 = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/((P0S + PS) * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT + 1) - alphaS * PS1
    dPh1dt = (betaT * PS1 * (SH1 - 1))/((P0S + PS1) * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap1 + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap1 * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH * PP1 * (ST - 1))/((P0P + PP1) * phiT * (IT + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT * PS2 * (SH2 - 1))/((P0S + PS2) * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap2 + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap2 * Pp2 * (IH + 1) - alphaP * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT * PS3 * (SH3 - 1))/((P0S + PS3) * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap3 + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap3 * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,6],'g--', linewidth=2.0)
plt.plot(t,n[:,19],'y--', linewidth=2.0)
plt.plot(t,n[:,32],'b--', linewidth=2.0)
plt.plot(t,n[:,45],'r--', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$S_{T} [t]$")
plt.legend(["$\u03B1_p = 0.0000001$","$\u03B1_p = 0.0000004$", "$\u03B1_p = 0.000004$","$\u03B1_p= 0.04$"])
plt.show()

# %% [markdown]
# ## Pathogen

# %%
# @title Pathogen (Host Vertebrate) dynamics from the microscale:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 65
    phiH = 0.005
    phiT = 0.09
    betaT = 0.05
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.009
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/(P0S + PS * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt,
            dITdt, dPPdt, dPgdt, dPzdt, dPkdt, dPsdt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

#plt.plot(t,n[:,6],'g-', linewidth=2.0)
plt.plot(t,n[:,8],'r-.', linewidth=2.0)
# plt.plot(t,n[:,23],'b--', linewidth=2.0)
# plt.plot(t,n[:,34],'r--', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$P_{P}[t]$")
plt.legend(["$P_{P}$"])
plt.show()

# %%
# @title Pathogen (Tick) dynamics from the microscale:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.05
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/(P0S + PS * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt,
            dITdt, dPPdt, dPgdt, dPzdt, dPkdt, dPsdt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

#plt.plot(t,n[:,6],'g-', linewidth=2.0)
plt.plot(t,n[:,2],'r-.', linewidth=2.0)
# plt.plot(t,n[:,23],'b--', linewidth=2.0)
# plt.plot(t,n[:,34],'r--', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$P_{S}[t]$")
plt.legend(["$P_{S}$"])
plt.show()

# %%
# @title Pathogen (Tick) dynamics under different $\alpha_{s}$ values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.05
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 0.08
    alphas1 = 0.2
    alphas2 = 0.5
    alphas3 = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/(P0S + PS * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas1 * Ps1)*(IT + 1) - alphaS * PS1
    dPh1dt = (betaT * PS1 * (SH1 - 1))/(P0S + PS1 * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH * PP1 * (ST - 1))/((P0P + PP1) * phiT * (IT + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas1 + mus)*Ps1

    dSH2dt = PiH - (betaT * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas2 * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT * PS2 * (SH2 - 1))/(P0S + PS2 * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH + 1) - alphaP * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas2 + mus)*Ps2

    dSH3dt = PiH - (betaT * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas3 * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT * PS3 * (SH3 - 1))/(P0S + PS3 * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas3 + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,2],'g--', linewidth=2.0)
plt.plot(t,n[:,15],'y--', linewidth=2.0)
plt.plot(t,n[:,28],'b--', linewidth=2.0)
plt.plot(t,n[:,41],'r--', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$P_{S} [t]$")
plt.legend(["$\u03B1_s = 0.08$","$\u03B1_s = 0.02$", "$\u03B1_s = 0.5$","$\u03B1_s = 50$"])
plt.show()

# %%
# @title Pathogen (Tick) dynamics under different $\alpha_{S}$ values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.05
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaS1 = 0.015
    alphaS2 = 0.018
    alphaS3 = 0.02
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/((P0S + PS) * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT1 + 1) - alphaS1 * PS1
    dPh1dt = (betaT * PS1 * (SH1 - 1))/((P0S + PS1) * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH * PP1 * (ST1 - 1))/((P0P + PP1) * phiT * (IT1 + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS2 * PS2
    dPh2dt = (betaT * PS2 * (SH2 - 1))/((P0S + PS2) * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH2 + 1) - alphaP * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS3 * PS3
    dPh3dt = (betaT * PS3 * (SH3 - 1))/((P0S + PS3) * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,2],'g-.', linewidth=2.0)
plt.plot(t,n[:,15],'y-.', linewidth=2.0)
plt.plot(t,n[:,28],'b-.', linewidth=2.0)
plt.plot(t,n[:,41],'r-.', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$P_{S} [t]$")
plt.legend(["$\u03B1_S = 0.011$","$\u03B1_S = 0.015$", "$\u03B1_S = 0.018$","$\u03B1_S = 0.02$"])
plt.show()

# %%
# @title Pathogen (Tick) dynamics under different $\beta_{H}$ values:

import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.05
    betaH = 0.12
    betaH1 = 0.17
    betaH2 = 0.22
    betaH3 = 0.3
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/((P0S + PS) * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT1 + 1) - alphaS * PS1
    dPh1dt = (betaT * PS1 * (SH1 - 1))/((P0S + PS1) * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH1 * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH1 * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH1 * PP1 * (ST1 - 1))/((P0P + PP1) * phiT * (IT1 + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT * PS2 * (SH2 - 1))/((P0S + PS2) * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH2 * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH2 * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH2 + 1) - alphaP * PP2
    dPg2dt = (betaH2 * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT * PS3 * (SH3 - 1))/((P0S + PS3) * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH3 * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH3 * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH3 * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,2],'g-.', linewidth=2.0)
plt.plot(t,n[:,15],'y-.', linewidth=2.0)
plt.plot(t,n[:,28],'b-.', linewidth=2.0)
plt.plot(t,n[:,41],'r-.', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$P_{S} [t]$")
plt.legend(["$\u03B2_H = 0.12$","$\u03B2_H = 0.17$", "$\u03B2_H = 0.22$","$\u03B2_H = 0.3$"])
plt.show()

# %%
# @title Pathogen (Host Vertebrate) dynamics under different $\beta_{T}$ values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.03
    betaT1 = 0.05
    betaT2 = 0.07
    betaT3 = 0.1
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.011
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/((P0S + PS) * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT1 * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT1 * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT + 1) - alphaS * PS1
    dPh1dt = (betaT1 * PS1 * (SH1 - 1))/((P0S + PS1) * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH * PP1 * (ST - 1))/((P0P + PP1) * phiT * (IT + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT2 * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT2 * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT2 * PS2 * (SH2 - 1))/((P0S + PS2) * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH2 + 1) - alphaP * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT3 * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT3 * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT3 * PS3 * (SH3 - 1))/((P0S + PS3) * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,8],'g-.', linewidth=2.0)
plt.plot(t,n[:,21],'y-.', linewidth=2.0)
plt.plot(t,n[:,34],'b-.', linewidth=2.0)
plt.plot(t,n[:,47],'r-.', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$P_{P} [t]$")
plt.legend(["$\u03B2_T = 0.03$","$\u03B2_T = 0.05$", "$\u03B2_T = 0.07$","$\u03B2_T = 0.1$"])
plt.show()

# %%
# @title Pathogen (Host Vertebrate) dynamics under different $\alpha_{p}$ values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.05
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.01
    alphap1 = 0.02
    alphap2 = 0.03
    alphap3 = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.11
    alphaP = 0.1
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/((P0S + PS) * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT1 + 1) - alphaS * PS1
    dPh1dt = (betaT * PS1 * (SH1 - 1))/((P0S + PS1) * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap1 + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap1 * Pp1 * (IH1 + 1) - alphaP * PP1
    dPg1dt = (betaH * PP1 * (ST1 - 1))/((P0P + PP1) * phiT * (IT1 + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT * PS2 * (SH2 - 1))/((P0S + PS2) * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap2 + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap2 * Pp2 * (IH2 + 1) - alphaP * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT * PS3 * (SH3 - 1))/((P0S + PS3) * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap3 + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap3 * Pp3 * (IH3 + 1) - alphaP * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,8],'g-.', linewidth=2.0)
plt.plot(t,n[:,21],'y-.', linewidth=2.0)
plt.plot(t,n[:,34],'b-.', linewidth=2.0)
plt.plot(t,n[:,47],'r-.', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$P_{P} [t]$")
plt.legend(["$\u03B1_p = 0.01$","$\u03B1_p = 0.02$", "$\u03B1_p = 0.03$","$\u03B1_p= 0.04$"])
plt.show()

# %%
# @title Pathogen (Host Vertebrate) dynamics under different $\alpha_{P}$ values:
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


def function(n,t):
    PiH = 30
    PiT = 150
    phiH = 0.005
    phiT = 0.09
    betaT = 0.05
    betaH = 0.12
    alphah = 90
    muh = 0.00002
    alphas = 50
    mus = 0.0002
    alpham = 80
    mum = 0.000002
    alphap = 0.04
    mup = 0.00006
    alphag = 0.04
    mug = 0.00002
    alphaz = 0.05
    muz = 0.2
    alphak = 30
    muk = 0.5
    alphaS = 0.11
    alphaP = 0.1
    alphaP1 = 0.2
    alphaP2 = 0.5
    alphaP3 = 0.8
    muH = 0.0027
    muT = 0.06
    deltaH = 0.06
    P0P = 0.5
    P0S = 0.5
    SH = n[0]
    IH = n[1]
    PS = n[2]
    Ph = n[3]
    Pm = n[4]
    Pp = n[5]
    ST = n[6]
    IT = n[7]
    PP = n[8]
    Pg = n[9]
    Pz = n[10]
    Pk = n[11]
    Ps = n[12]
    SH1 = n[13]
    IH1 = n[14]
    PS1 = n[15]
    Ph1 = n[16]
    Pm1 = n[17]
    Pp1 = n[18]
    ST1 = n[19]
    IT1 = n[20]
    PP1 = n[21]
    Pg1 = n[22]
    Pz1 = n[23]
    Pk1 = n[24]
    Ps1 = n[25]
    SH2 = n[26]
    IH2 = n[27]
    PS2 = n[28]
    Ph2 = n[29]
    Pm2 = n[30]
    Pp2 = n[31]
    ST2 = n[32]
    IT2 = n[33]
    PP2 = n[34]
    Pg2 = n[35]
    Pz2 = n[36]
    Pk2 = n[37]
    Ps2 = n[38]
    SH3 = n[39]
    IH3 = n[40]
    PS3 = n[41]
    Ph3 = n[42]
    Pm3 = n[43]
    Pp3 = n[44]
    ST3 = n[45]
    IT3 = n[46]
    PP3 = n[47]
    Pg3 = n[48]
    Pz3 = n[49]
    Pk3 = n[50]
    Ps3 = n[51]
    dSHdt = PiH - (betaT * PS * SH)/(P0S + PS) - muH*SH
    dIHdt = (betaT * PS * SH)/(P0S + PS) - (deltaH + muH)*IH
    dPSdt = (alphas * Ps)*(IT + 1) - alphaS * PS
    dPhdt = (betaT * PS * (SH - 1))/((P0S + PS) * phiH * (IH + 1)) - (alphah + muh) * Ph
    dPmdt = alphah * Ph - (alpham + mum) * Pm
    dPpdt = alpham * Pm - (alphap + mup) * Pp
    dSTdt = PiT - (betaH * PP * ST)/(P0P + PP) - muT * ST
    dITdt = (betaH * PP * ST)/(P0P + PP) - muT * IT
    dPPdt = alphap * Pp * (IH + 1) - alphaP * PP
    dPgdt = (betaH * PP * (ST - 1))/((P0P + PP) * phiT * (IT + 1)) - (alphag + mug) * Pg
    dPzdt = alphag * Pg - (alphaz + muz) * Pz
    dPkdt = alphaz * Pz - (alphak + muk) * Pk
    dPsdt = alphak * Pk - (alphas + mus)*Ps

    dSH1dt = PiH - (betaT * PS1 * SH1)/(P0S + PS1) - muH*SH1
    dIH1dt = (betaT * PS1 * SH1)/(P0S + PS1) - (deltaH + muH)*IH1
    dPS1dt = (alphas * Ps1)*(IT + 1) - alphaS * PS1
    dPh1dt = (betaT * PS1 * (SH1 - 1))/((P0S + PS1) * phiH * (IH1 + 1)) - (alphah + muh) * Ph1
    dPm1dt = alphah * Ph1 - (alpham + mum) * Pm1
    dPp1dt = alpham * Pm1 - (alphap + mup) * Pp1
    dST1dt = PiT - (betaH * PP1 * ST1)/(P0P + PP1) - muT * ST1
    dIT1dt = (betaH * PP1 * ST1)/(P0P + PP1) - muT * IT1
    dPP1dt = alphap * Pp1 * (IH1 + 1) - alphaP1 * PP1
    dPg1dt = (betaH * PP1 * (ST - 1))/((P0P + PP1) * phiT * (IT + 1)) - (alphag + mug) * Pg1
    dPz1dt = alphag * Pg1 - (alphaz + muz) * Pz1
    dPk1dt = alphaz * Pz1 - (alphak + muk) * Pk1
    dPs1dt = alphak * Pk1 - (alphas + mus)*Ps1

    dSH2dt = PiH - (betaT * PS2 * SH2)/(P0S + PS2) - muH*SH2
    dIH2dt = (betaT * PS2 * SH2)/(P0S + PS2) - (deltaH + muH)*IH2
    dPS2dt = (alphas * Ps2)*(IT2 + 1) - alphaS * PS2
    dPh2dt = (betaT * PS2 * (SH2 - 1))/((P0S + PS2) * phiH * (IH2 + 1)) - (alphah + muh) * Ph2
    dPm2dt = alphah * Ph2 - (alpham + mum) * Pm2
    dPp2dt = alpham * Pm2 - (alphap + mup) * Pp2
    dST2dt = PiT - (betaH * PP2 * ST2)/(P0P + PP2) - muT * ST2
    dIT2dt = (betaH * PP2 * ST2)/(P0P + PP2) - muT * IT2
    dPP2dt = alphap * Pp2 * (IH2 + 1) - alphaP2 * PP2
    dPg2dt = (betaH * PP2 * (ST2 - 1))/((P0P + PP2) * phiT * (IT2 + 1)) - (alphag + mug) * Pg2
    dPz2dt = alphag * Pg2 - (alphaz + muz) * Pz2
    dPk2dt = alphaz * Pz2 - (alphak + muk) * Pk2
    dPs2dt = alphak * Pk2 - (alphas + mus)*Ps2

    dSH3dt = PiH - (betaT * PS3 * SH3)/(P0S + PS3) - muH*SH3
    dIH3dt = (betaT * PS3 * SH3)/(P0S + PS3) - (deltaH + muH)*IH3
    dPS3dt = (alphas * Ps3)*(IT3 + 1) - alphaS * PS3
    dPh3dt = (betaT * PS3 * (SH3 - 1))/((P0S + PS3) * phiH * (IH3 + 1)) - (alphah + muh) * Ph3
    dPm3dt = alphah * Ph3 - (alpham + mum) * Pm3
    dPp3dt = alpham * Pm3 - (alphap + mup) * Pp3
    dST3dt = PiT - (betaH * PP3 * ST3)/(P0P + PP3) - muT * ST3
    dIT3dt = (betaH * PP3 * ST3)/(P0P + PP3) - muT * IT3
    dPP3dt = alphap * Pp3 * (IH3 + 1) - alphaP3 * PP3
    dPg3dt = (betaH * PP3 * (ST3 - 1))/((P0P + PP3) * phiT * (IT3 + 1)) - (alphag + mug) * Pg3
    dPz3dt = alphag * Pg3 - (alphaz + muz) * Pz3
    dPk3dt = alphaz * Pz3 - (alphak + muk) * Pk3
    dPs3dt = alphak * Pk3 - (alphas + mus)*Ps3


    return [dSHdt, dIHdt, dPSdt, dPhdt, dPmdt, dPpdt, dSTdt, dITdt, dPPdt, dPgdt, dPzdt,
            dPkdt, dPsdt, dSH1dt, dIH1dt, dPS1dt, dPh1dt, dPm1dt, dPp1dt, dST1dt, dIT1dt, dPP1dt,
            dPg1dt, dPz1dt, dPk1dt, dPs1dt, dSH2dt, dIH2dt, dPS2dt, dPh2dt, dPm2dt, dPp2dt, dST2dt,
            dIT2dt, dPP2dt, dPg2dt, dPz2dt, dPk2dt, dPs2dt, dSH3dt, dIH3dt, dPS3dt, dPh3dt, dPm3dt,
            dPp3dt, dST3dt, dIT3dt, dPP3dt, dPg3dt, dPz3dt, dPk3dt, dPs3dt]

t = np.linspace(0,400,1000)
s0=[2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0,
    2000, 10, 0.02, 0, 0, 0, 12000, 300, 0.9, 0, 0, 0, 0]

n = odeint(function,s0,t)

plt.plot(t,n[:,8],'g-.', linewidth=2.0)
plt.plot(t,n[:,21],'y-.', linewidth=2.0)
plt.plot(t,n[:,34],'b-.', linewidth=2.0)
plt.plot(t,n[:,47],'r-.', linewidth=2.0)
plt.xlabel("t")
plt.ylabel("$P_{P} [t]$")
plt.legend(["$\u03B1_P = 0.1$","$\u03B1_P = 0.2$", "$\u03B1_P = 0.5$","$\u03B1_P= 0.8$"])
plt.show()
